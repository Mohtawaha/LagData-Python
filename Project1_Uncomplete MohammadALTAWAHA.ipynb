# %%
## Importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plot   ### For Data Visualization

# %%
# Import the data 

df= pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
## Inspecting & Exploring our data 

df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
df.tail()
# Out:
#        School DBN           School Name School Level  \
# 212326     84X717  Icahn Charter School          K-8
# 212327     84X717  Icahn Charter School          K-8
# 212328     84X717  Icahn Charter School          K-8
# 212329     84X717  Icahn Charter School          K-8
# 212330     84X717  Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 212326           Living Environment  2016             8          s
# 212327           Living Environment  2016             5          s
# 212328           Living Environment  2017             6          s
# 212329           Living Environment  2017             4          s
# 212330  U.S. History and Government  2015             1          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 212326                       s                        s
# 212327                       s                        s
# 212328                       s                        s
# ...

# %%
df.count()
# Out:
# School DBN                     212331
# School Name                    212331
# School Level                   212331
# Regents Exam                   212321
# Year                           212331
# Total Tested                   212331
# Mean Score                     212331
# Number Scoring Below 65        212331
# Percent Scoring Below 65       212331
# Number Scoring 65 or Above     212331
# Percent Scoring 65 or Above    212331
# Number Scoring 80 or Above     212331
# Percent Scoring 80 or Above    212331
# Number Scoring CR              212331
# Percent Scoring CR             212331
# dtype: int64

# %%
## Finding Null Values

df.isnull().sum()
# Out:
# School DBN                      0
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# Number Scoring CR               0
# Percent Scoring CR              0
# dtype: int64

# %%
# Cleaning the data - after finding null values in Regents Exam column , then droped the rows

df.dropna(subset=['Regents Exam'], inplace=True)

# %%
## after deleting null values  , to make sure its been deleted

df.isna().any()
# Out:
# School DBN                     False
# School Name                    False
# School Level                   False
# Regents Exam                   False
# Year                           False
# Total Tested                   False
# Mean Score                     False
# Number Scoring Below 65        False
# Percent Scoring Below 65       False
# Number Scoring 65 or Above     False
# Percent Scoring 65 or Above    False
# Number Scoring 80 or Above     False
# Percent Scoring 80 or Above    False
# Number Scoring CR              False
# Percent Scoring CR             False
# dtype: bool

# %%
### groping that be useful in the comparison later

# %%
## grouping School Levels

df['School DBN'].groupby (df['School Level']).count().sort_values(ascending= False)
# Out:
# School Level
# High school                        151160
# Secondary School                    30242
# Junior High-Intermediate-Middle     15742
# K-12 all grades                      8294
# K-8                                  6858
# Elementary                             25
# Name: School DBN, dtype: int64

# %%
df['School DBN'].groupby (df['School DBN']).count().sort_values(ascending= False)
# Out:
# School DBN
# 22K425    490
# 26Q430    490
# 21K525    489
# 30Q450    489
# 21K540    488
#          ...
# 17K334      5
# 19K302      5
# 19K202      5
# 27Q183      5
# 84M385      5
# Name: School DBN, Length: 1018, dtype: int64

# %%
## grouping Regents Exams 

df['School DBN'].groupby (df['Regents Exam']).count()
# Out:
# Regents Exam
# Algebra2/Trigonometry              10788
# Common Core Algebra                29254
# Common Core Algebra2                7915
# Common Core English                19878
# Common Core Geometry               15267
# English                            11091
# Geometry                            8509
# Global History and Geography       19192
# Integrated Algebra                 11022
# Living Environment                 25539
# Physical Settings/Chemistry        11670
# Physical Settings/Earth Science    15971
# Physical Settings/Physics           5799
# U.S. History and Government        20426
# Name: School DBN, dtype: int64

# %%
ChosenSchool = df.loc[df['School DBN'].str.contains('04M610')]

# %%
## Other Shcools that not be chosen, By using telda  ###(~)### Thanks for Selvia ###

# %%
OtherSchools= df.loc[~df['School DBN'].str.contains('04M610')]

# %%
df_Manhattan=df[df['School DBN'].str.contains('M')]

# %%
dfNoNAS= ChosenSchool[~ChosenSchool['Number Scoring Below 65'].str.contains('na','s')]

# %%
OtherSchoolsNoNAS= OtherSchools[~OtherSchools['Number Scoring Below 65'].str.contains('na','s')]

# %%
df_SeconderySchool= df[df['School Level'].str.contains('Secondary School')]

# %%
df_SeconderySchool
# Out:
#        School DBN                       School Name      School Level  \
# 96         01M450        East Side Community School  Secondary School
# 97         01M450        East Side Community School  Secondary School
# 98         01M450        East Side Community School  Secondary School
# 99         01M450        East Side Community School  Secondary School
# 100        01M450        East Side Community School  Secondary School
# ...           ...                               ...               ...
# 212213     84X703  Bronx Preparatory Charter School  Secondary School
# 212214     84X703  Bronx Preparatory Charter School  Secondary School
# 212215     84X703  Bronx Preparatory Charter School  Secondary School
# 212216     84X703  Bronx Preparatory Charter School  Secondary School
# 212217     84X703  Bronx Preparatory Charter School  Secondary School
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# ...

# %%
df_04M610 = df.loc[df['Regents Exam'].str.contains('Common Core Algebra')]

# %%
# Descriptive statistics for the selected school

# %%
ChosenSchoolChosenScore = df.loc[df['School DBN'] == df['School DBN'], 'Number Scoring Below 65'].describe()

# %%
ChosenSchool.describe()
# Out:
# count          4
# unique         4
# top       212331
# freq           1
# Name: Number Scoring Below 65, dtype: int64

# %%
BoroughCompare = df_Manhattan['Number Scoring Below 65'].describe()

# %%
BoroughCompare.describe()
# Out:
# count         4
# unique        4
# top       48502
# freq          1
# Name: Number Scoring Below 65, dtype: int64
